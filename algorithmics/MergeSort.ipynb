# %% [markdown]
# # Mergesort
#
# - $\text{KeyComp} \leq  ⌈\log_2 n⌉- 2^{⌈\log2 n⌉} + 1$
#
# - $\text{time} \in O(n\log n)$
#
# - *not in situ*

# %% [markdown]
# ##### Algorithm Idea
#
# The mergesort algorithm at its core has two main actions:
# 1. Sorting the array of the length 2 (by swapping the elements if needed)
# 2. `merge`: Merging two sorted arrays by the following means:
#     - save the copy of the array
#     - split the copy into two parts
#     - start iterating through both parts, comparing elements one by one and putting whichever is less to the beginning of the (target) list. Continue the iteration to the next element, if the last element added to the target array was from this part.
#     - after you reach the end of one of the parts, fill the rest of the target array with the elements of the part that didn't reach the end.
#
# ##### Proof ideas
# - for correctness induct on length.
# - for number of comparisons: assume $n=2^k$ for a $k\in \mathbb{N}$ and use recursion $\text{KeyComp}(1)=0, \text{KeyComp}(n)=n-1+2 \cdot \text{KeyComp}(\frac{n}{2})$

# %%
def merge(A, v, I):
    return

def mergesort(A):
    return

# %% [markdown]
# #### `Merge()`
#
# $\text{KeyComp} \in (⌊\frac{n}{2}⌋, |n|)$
#
#
# **The lower bound is true for ANY algorithm that merges two sorted sets.**
# This means our merging algorithm is **optimal**.

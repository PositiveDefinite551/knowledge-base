# %% [markdown]
# # Maxsum

# %% [markdown]
# Let an array of whole numbers be given. What is the greatest sum one can get by summing up *neighbouring* elements?

# %% [markdown]
# We implement the following algorithm:

# %%
def maxsum(a):
    k = 0
    Max = a[0]
    MaxSuffix = a[0]
    while k<n:
        k += 1
        Maxsuffix = max(MaxSuffix + a[k],a[k])
        Max = max(MaxSuffix, Max)
    return Max

# %% [markdown]
# To show the corectness of the algorithm, we observe that for $k \in \mathbb{N}$ $$\text{inv}(k): \text{max} \{f(i,j): 0\leq i,j \leq k\}$$ $$\text{MaxSuffix} = \text{max} \{f(i,k) : i\leq k\}$$ is invariant of the while-loop

# %% [markdown]
# #### Runtime analysis
# The while loop is executed n-1 times, each time 4 basic operations take place, which gives $$3n-3$$ basic operation. Which means the algorithm works in $O(n)$ time. It requires no extra space.
